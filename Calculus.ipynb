# %%
# Great Resource: https://jverzani.github.io/CalculusWithJuliaNotes.jl/precalc.html
using Plots

# %%
f(x) = 1 - x^2/2
plot(f, -3, 3)

# %%
f(x) = x^2 - x
plot(f, -2, 2)
plot!(zero, -2, 2)

# %%
x = 1
quotient, remainder = divrem(x^4 + 2x^2 + 5, x - 2)
# Out:
# (-8, 0)

# %%
f(x) = (1 + x)^(1/x)
xs = [1/10^i for i in 1:5]
[xs f.(xs)]
# Out:
# 5×2 Matrix{Float64}:
#  0.1     2.59374
#  0.01    2.70481
#  0.001   2.71692
#  0.0001  2.71815
#  1.0e-5  2.71827
